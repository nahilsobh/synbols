# %%
# Specify variables
from haven import haven_jupyter as hj
from haven import haven_results as hr
from haven import haven_utils as s
from haven import haven_utils as hu
import matplotlib as mpl
mpl.rc('image', cmap='tab20c')


# please define the path to the experiments
savedir_base = "/mnt/home/fbranchaud/synbols_ckpt"
from benchmarks.scripts.active_learning import EXP_GROUPS
exp_list = EXP_GROUPS['active_char_noise']

# get specific experiments, for example, {'model':'resnet34'}
filterby_list = None
# group the experiments based on a hyperparameter, for example, ['dataset']
groupby_list = None
verbose = 0

# plot vars
y_metrics='test_loss'
x_metric='num_samples'
log_metric_list = ['train_loss']
map_exp_list = []
title_list=['query_size']
legend_list=['heuristic', 'iterations']
avg_across='seed'
legend_format = '{}, I={}'

# get experiments
rm = hr.ResultManager(exp_list=exp_list, 
                      savedir_base=savedir_base, 
                      filterby_list=filterby_list,
                      verbose=verbose
                     )
kwargs = {
    'y_metric': y_metrics,
    'x_metric': x_metric,
    'log_metric_list': log_metric_list,
    'map_exp_list': map_exp_list,
    'title_list':title_list,
    'legend_list': legend_list,
    'avg_across': avg_across,
    'figsize': (20, 15),
    'legend_format': legend_format,
    'groupby_list': ['query_size']
}

df = rm.get_exp_list_df()

# launch dashboard
rm.get_plot(**kwargs)
# Out:
# [<Figure size 1440x1080 with 1 Axes>,
#  <Figure size 1440x1080 with 1 Axes>,
#  <Figure size 1440x1080 with 1 Axes>]

# %%
# please define the path to the experiments
savedir_base = "/mnt/home/fbranchaud/synbols_ckpt"
savedir_base = "/mnt/projects/bayesian-active-learning/synbols_ckpt"
from benchmarks.scripts.active_learning import EXP_GROUPS
exp_list = EXP_GROUPS['active_char_shuffle']

# get specific experiments, for example, {'model':'resnet34'}
filterby_list = None
# group the experiments based on a hyperparameter, for example, ['dataset']
groupby_list = None
verbose = 0

# plot vars
y_metrics='test_loss'
x_metric='num_samples'
log_metric_list = ['train_loss']
map_exp_list = []
title_list=['query_size']
legend_list=['heuristic', 'iterations', 'shuffle_prop']
avg_across='seed'
legend_format = '{}, I={}, SP={}'

# get experiments
rm = hr.ResultManager(exp_list=exp_list,
                      savedir_base=savedir_base,
                      filterby_list=filterby_list,
                      verbose=verbose
                     )
kwargs = {
    'y_metric': y_metrics,
    'x_metric': x_metric,
    'log_metric_list': log_metric_list,
    'map_exp_list': map_exp_list,
    'title_list':title_list,
    'legend_list': legend_list,
    'avg_across': avg_across,
    'figsize': (20, 15),
    'legend_format': legend_format,
    'groupby_list': ['query_size']
}


# launch dashboard
rm.get_plot(**kwargs)
# Out:
# [<Figure size 1440x1080 with 1 Axes>]

# %%
# please define the path to the experiments
savedir_base = "/mnt/projects/bayesian-active-learning/synbols_ckpt"
from benchmarks.scripts.active_learning import EXP_GROUPS
exp_list = EXP_GROUPS['active_char_calibrated']

# get specific experiments, for example, {'model':'resnet34'}
filterby_list = None
# group the experiments based on a hyperparameter, for example, ['dataset']
groupby_list = None
verbose = 0

# plot vars
y_metrics='test_loss'
x_metric='num_samples'
log_metric_list = ['train_loss']
map_exp_list = []
title_list=['query_size']
legend_list=['heuristic', 'iterations']
avg_across='seed'
legend_format = '{}, I={}'

# get experiments
rm = hr.ResultManager(exp_list=exp_list,
                      savedir_base=savedir_base,
                      filterby_list=filterby_list,
                      verbose=verbose
                     )
kwargs = {
    'y_metric': y_metrics,
    'x_metric': x_metric,
    'log_metric_list': log_metric_list,
    'map_exp_list': map_exp_list,
    'title_list':title_list,
    'legend_list': legend_list,
    'avg_across': avg_across,
    'figsize': (10, 5),
    'legend_format': legend_format,
    'groupby_list': ['query_size']
}


# launch dashboard
rm.get_plot(**kwargs)
# Out:
# [<Figure size 720x360 with 1 Axes>]

# %%
# please define the path to the experiments
savedir_base = "/mnt/projects/bayesian-active-learning/synbols_ckpt"
from benchmarks.scripts.active_learning import EXP_GROUPS
exp_list = EXP_GROUPS['active_char_betabald']

# get specific experiments, for example, {'model':'resnet34'}
filterby_list = None
# group the experiments based on a hyperparameter, for example, ['dataset']
groupby_list = None
verbose = 0

# plot vars
y_metrics='test_loss'
x_metric='num_samples'
log_metric_list = ['train_loss']
map_exp_list = []
title_list=['query_size']
legend_list=['heuristic', 'iterations']
avg_across='seed'
legend_format = '{}, I={}'

# get experiments
rm = hr.ResultManager(exp_list=exp_list,
                      savedir_base=savedir_base,
                      filterby_list=filterby_list,
                      verbose=verbose
                     )
kwargs = {
    'y_metric': y_metrics,
    'x_metric': x_metric,
    'log_metric_list': log_metric_list,
    'map_exp_list': map_exp_list,
    'title_list':title_list,
    'legend_list': legend_list,
    'avg_across': avg_across,
    'figsize': (20, 15),
    'legend_format': legend_format,
    'groupby_list': ['query_size']
}


# launch dashboard
rm.get_plot(**kwargs)
# Out:
# [<Figure size 1440x1080 with 1 Axes>]

# %%
# please define the path to the experiments
savedir_base = "/mnt/projects/bayesian-active-learning/synbols_ckpt"
from benchmarks.scripts.active_learning import EXP_GROUPS
exp_list = EXP_GROUPS['active_char_mixup']

# get specific experiments, for example, {'model':'resnet34'}
filterby_list = None
# group the experiments based on a hyperparameter, for example, ['dataset']
groupby_list = None
verbose = 0

# plot vars
y_metrics='test_loss'
x_metric='num_samples'
log_metric_list = ['train_loss']
map_exp_list = []
title_list=['query_size']
legend_list=['heuristic', 'iterations', 'mixup_alpha']
avg_across='seed'
legend_format = '{}, I={}, Alpha={}'

# get experiments
rm = hr.ResultManager(exp_list=exp_list,
                      savedir_base=savedir_base,
                      filterby_list=filterby_list,
                      verbose=verbose
                     )
kwargs = {
    'y_metric': y_metrics,
    'x_metric': x_metric,
    'log_metric_list': log_metric_list,
    'map_exp_list': map_exp_list,
    'title_list':title_list,
    'legend_list': legend_list,
    'avg_across': avg_across,
    'figsize': (20, 15),
    'legend_format': legend_format,
    'groupby_list': ['query_size']
}


# launch dashboard
rm.get_plot(**kwargs)
# Out:
# [<Figure size 1440x1080 with 1 Axes>]

# %%
# Specify variables
from haven import haven_jupyter as hj
from haven import haven_results as hr
from haven import haven_utils as s
from haven import haven_utils as hu
import matplotlib as mpl
mpl.rc('image', cmap='tab20c')


# please define the path to the experiments
savedir_base = "/mnt/projects/bayesian-active-learning/synbols_ckpt"
from benchmarks.scripts.active_learning import EXP_GROUPS
exp_list = EXP_GROUPS['active_char_label_noise']

# get specific experiments, for example, {'model':'resnet34'}
filterby_list = None
# group the experiments based on a hyperparameter, for example, ['dataset']
groupby_list = None
verbose = 0

# plot vars
y_metrics='test_loss'
x_metric='num_samples'
log_metric_list = ['train_loss']
map_exp_list = []
title_list=['query_size']
legend_list=['heuristic', 'iterations']
avg_across='seed'
legend_format = '{}, I={}'

# get experiments
rm = hr.ResultManager(exp_list=exp_list,
                      savedir_base=savedir_base,
                      filterby_list=filterby_list,
                      verbose=verbose
                     )
kwargs = {
    'y_metric': y_metrics,
    'x_metric': x_metric,
    'log_metric_list': log_metric_list,
    'map_exp_list': map_exp_list,
    'title_list':title_list,
    'legend_list': legend_list,
    'avg_across': avg_across,
    'figsize': (20, 15),
    'legend_format': legend_format,
    'groupby_list': ['query_size']
}

df = rm.get_exp_list_df()

# launch dashboard
rm.get_plot(**kwargs)

# %%
# Specify variables
from haven import haven_jupyter as hj
from haven import haven_results as hr
from haven import haven_utils as s
from haven import haven_utils as hu
import matplotlib as mpl
mpl.rc('image', cmap='tab20c')


# please define the path to the experiments
savedir_base = "/mnt/projects/bayesian-active-learning/synbols_ckpt"
from benchmarks.scripts.active_learning import EXP_GROUPS
exp_list = EXP_GROUPS['active_char_pixel_noise']

# get specific experiments, for example, {'model':'resnet34'}
filterby_list = None
# group the experiments based on a hyperparameter, for example, ['dataset']
groupby_list = None
verbose = 0

# plot vars
y_metrics='test_loss'
x_metric='num_samples'
log_metric_list = ['train_loss']
map_exp_list = []
title_list=['query_size']
legend_list=['heuristic', 'iterations']
avg_across='seed'
legend_format = '{}, I={}'

# get experiments
rm = hr.ResultManager(exp_list=exp_list,
                      savedir_base=savedir_base,
                      filterby_list=filterby_list,
                      verbose=verbose
                     )
kwargs = {
    'y_metric': y_metrics,
    'x_metric': x_metric,
    'log_metric_list': log_metric_list,
    'map_exp_list': map_exp_list,
    'title_list':title_list,
    'legend_list': legend_list,
    'avg_across': avg_across,
    'figsize': (10, 5),
    'legend_format': legend_format,
    'groupby_list': ['query_size']
}

df = rm.get_exp_list_df()

# launch dashboard
rm.get_plot(**kwargs)#%%
# Out:
# [<Figure size 720x360 with 1 Axes>]

# %%
# Specify variables
from haven import haven_jupyter as hj
from haven import haven_results as hr
from haven import haven_utils as s
from haven import haven_utils as hu
import matplotlib as mpl
mpl.rc('image', cmap='tab20c')


# please define the path to the experiments
savedir_base = "/mnt/projects/bayesian-active-learning/synbols_ckpt"
from benchmarks.scripts.active_learning import EXP_GROUPS
exp_list = EXP_GROUPS['active_char_label_noise']

# get specific experiments, for example, {'model':'resnet34'}
filterby_list = None
# group the experiments based on a hyperparameter, for example, ['dataset']
groupby_list = None
verbose = 0

# plot vars
y_metrics='test_loss'
x_metric='num_samples'
log_metric_list = ['train_loss']
map_exp_list = []
title_list=['query_size']
legend_list=['heuristic', 'iterations']
avg_across='seed'
legend_format = '{}, I={}'

# get experiments
rm = hr.ResultManager(exp_list=exp_list,
                      savedir_base=savedir_base,
                      filterby_list=filterby_list,
                      verbose=verbose
                     )
kwargs = {
    'y_metric': y_metrics,
    'x_metric': x_metric,
    'log_metric_list': log_metric_list,
    'map_exp_list': map_exp_list,
    'title_list':title_list,
    'legend_list': legend_list,
    'avg_across': avg_across,
    'figsize': (10, 5),
    'legend_format': legend_format,
    'groupby_list': ['query_size']
}

df = rm.get_exp_list_df()

# launch dashboard
rm.get_plot(**kwargs)
# Out:
# [<Figure size 720x360 with 1 Axes>]

# %%
# Specify variables
from haven import haven_jupyter as hj
from haven import haven_results as hr
from haven import haven_utils as s
from haven import haven_utils as hu
import matplotlib as mpl
mpl.rc('image', cmap='tab20c')


# please define the path to the experiments
savedir_base = "/mnt/projects/bayesian-active-learning/synbols_ckpt"
from benchmarks.scripts.active_learning import EXP_GROUPS
exp_list = EXP_GROUPS['active_char_calibrated']

# get specific experiments, for example, {'model':'resnet34'}
filterby_list = None
# group the experiments based on a hyperparameter, for example, ['dataset']
groupby_list = None
verbose = 0

# plot vars
y_metrics='test_loss'
x_metric='num_samples'
log_metric_list = ['train_loss']
map_exp_list = []
title_list=['query_size']
legend_list=['heuristic', 'iterations', 'calibrate']
avg_across='seed'
legend_format = '{}, I={}, Calibrate={}'

# get experiments
rm = hr.ResultManager(exp_list=exp_list,
                      savedir_base=savedir_base,
                      filterby_list=filterby_list,
                      verbose=verbose
                     )
kwargs = {
    'y_metric': y_metrics,
    'x_metric': x_metric,
    'log_metric_list': log_metric_list,
    'map_exp_list': map_exp_list,
    'title_list':title_list,
    'legend_list': legend_list,
    'avg_across': avg_across,
    'figsize': (20, 15),
    'legend_format': legend_format,
    'groupby_list': []
}

df = rm.get_exp_list_df()

# launch dashboard
rm.get_plot(**kwargs)
# Out:
# [<Figure size 1440x1080 with 1 Axes>]

# %%
print(df.columns)

df2 = df[df['heuristic'] == 'entropy']
df2 = df2[df2['query_size'] == 100]
df2 = df2[df2['calibrate'] == False]
print(df2['exp_id'])
# Out:
# Index(['exp_id', 'lr', 'batch_size', 'model', 'calibrate', 'seed', 'mu',
#        'reg_factor', 'backbone', 'num_classes', 'query_size', 'learning_epoch',
#        'heuristic', 'iterations', 'max_epoch', 'imagenet_pretraining',
#        'dataset'],
#       dtype='object')
# 2     d3e909536729c8fca4746de5f9040c27
# 5     7469bf54070bcb7d2d719bf3b0791269
# 8     7e37f0e96a15357a78052ccbca6ddd97
# 11    06ceef5d00931ed64efd02153f025d0e
# Name: exp_id, dtype: object

# %%
print(df.columns)

df2 = df[df['heuristic'] == 'entropy']
df2 = df2[df2['query_size'] == 100]
df2 = df2[df2['iterations'] == 20]
print(df2['exp_id'])
# Out:
# Index(['exp_id', 'lr', 'batch_size', 'model', 'seed', 'mu', 'reg_factor',
#        'backbone', 'num_classes', 'query_size', 'learning_epoch', 'heuristic',
#        'iterations', 'max_epoch', 'imagenet_pretraining', 'dataset'],
#       dtype='object')
# 57    1e098eed78c5044fe470769409260b3e
# 69    9b994f8dd1eecae17fc80bd8310b7638
# 81    74d2a210dd3c5deed7f8ac792e86c374
# 93    8d830d94697b22bfcad42cb9d0012d23
# Name: exp_id, dtype: object
