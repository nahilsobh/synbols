# %%
# Specify variables
from haven import haven_jupyter as hj
from haven import haven_results as hr
from haven import haven_utils as s
from haven import haven_utils as hu
import matplotlib as mpl
mpl.rc('image', cmap='tab20c')

# %%
from haven import haven_results as hr
# please define the path to the experiments
savedir_base = "/mnt/projects/bayesian-active-learning/synbols_ckpt"
from benchmarks.scripts.active_learning import EXP_GROUPS
exp_list = EXP_GROUPS['active_char_calibrated']

# get specific experiments, for example, {'model':'resnet34'}
filterby_list = {'heuristic': ['entropy', 'bald'], 'calibrate': True}
# group the experiments based on a hyperparameter, for example, ['dataset']
groupby_list = None
verbose = 0

# plot vars
y_metrics='test_loss'
x_metric='num_samples'
log_metric_list = ['train_loss']
map_exp_list = []
title_list=['query_size']
legend_list=['heuristic']
avg_across='seed'
legend_format = '{}'

# get experiments
rm = hr.ResultManager(exp_list=exp_list,
                      savedir_base=savedir_base,
                      filterby_list=filterby_list,
                      verbose=verbose
                     )
kwargs = {
    'y_metric': y_metrics,
    'x_metric': x_metric,
    'log_metric_list': log_metric_list,
    'map_exp_list': map_exp_list,
    'title_list':title_list,
    'legend_list': legend_list,
    'avg_across': avg_across,
    'figsize': (10, 10),
    'legend_format': legend_format,
    'groupby_list': ['query_size']
}


# launch dashboard
rm.get_plot(**kwargs)
# Out:
# []

# %%
from haven import haven_results as hr
# please define the path to the experiments
savedir_base = "/mnt/projects/bayesian-active-learning/synbols_ckpt"
from benchmarks.scripts.active_learning import EXP_GROUPS
exp_list = EXP_GROUPS['active_char_calibrated']

# get specific experiments, for example, {'model':'resnet34'}
filterby_list = None
# group the experiments based on a hyperparameter, for example, ['dataset']
groupby_list = None
verbose = 0

# plot vars
y_metrics='test_loss'
x_metric='num_samples'
log_metric_list = ['train_loss']
map_exp_list = []
title_list=['query_size']
legend_list=['heuristic', 'iterations']
avg_across='seed'
legend_format = '{}, I={}'

# get experiments
rm = hr.ResultManager(exp_list=exp_list,
                      savedir_base=savedir_base,
                      filterby_list=filterby_list,
                      verbose=verbose
                     )
kwargs = {
    'y_metric': y_metrics,
    'x_metric': x_metric,
    'log_metric_list': log_metric_list,
    'map_exp_list': map_exp_list,
    'title_list':title_list,
    'legend_list': legend_list,
    'avg_across': avg_across,
    'figsize': (10, 5),
    'legend_format': legend_format,
    'groupby_list': ['query_size'],
  'xlim': (0, 20000)
}


# launch dashboard
rm.get_plot(**kwargs)
df = rm.get_exp_list_df()

# %%
print(df[df['heuristic'] == 'bald'])
# Out:
#                               exp_id     lr  batch_size  \
# 0   7670387c89c90220afb37f4ca06b8c9a  0.001          32
# 1   0e797c0eb3836aaae1664406ea6fd3ee  0.001          32
# 6   0387155b2473bfc5db1764ecd928cb40  0.001          32
# 7   8136b0d3cc12d3408dd9fe38d1bcedae  0.001          32
# 12  05873efce0fbd25af6fbdbe83f34d1c0  0.001          32
# 13  8e3a04fef46938aacbf2f7b09da0cb89  0.001          32
# 18  f3f3411285a9769f9a1da4ad5996bdb3  0.001          32
# 19  9810134272e5e1eabb1b9097be14079b  0.001          32
#
#                          model  seed     mu  reg_factor backbone  num_classes  \
# 0   calibrated_active_learning  1337  0.001      0.0001    vgg16           52
# 1   calibrated_active_learning  1337  0.001      0.0001    vgg16           52
# 6   calibrated_active_learning  1338  0.001      0.0001    vgg16           52
# 7   calibrated_active_learning  1338  0.001      0.0001    vgg16           52
# 12  calibrated_active_learning  1339  0.001      0.0001    vgg16           52
# 13  calibrated_active_learning  1339  0.001      0.0001    vgg16           52
# 18  calibrated_active_learning  1340  0.001      0.0001    vgg16           52
# 19  calibrated_active_learning  1340  0.001      0.0001    vgg16           52
#
#     query_size  learning_epoch heuristic  iterations  max_epoch  \
# 0          100              10      bald          20       2000
# 1          100              10      bald          20       2000
# 6          100              10      bald          20       2000
# 7          100              10      bald          20       2000
# 12         100              10      bald          20       2000
# 13         100              10      bald          20       2000
# 18         100              10      bald          20       2000
# 19         100              10      bald          20       2000
#
#     imagenet_pretraining  calibrate  \
# 0                   True       True
# 1                   True      False
# 6                   True       True
# 7                   True      False
# 12                  True       True
# 13                  True      False
# 18                  True       True
# 19                  True      False
#
#                                               dataset
# 0   {'path': '/mnt/datasets/public/research/synbol...
# 1   {'path': '/mnt/datasets/public/research/synbol...
# 6   {'path': '/mnt/datasets/public/research/synbol...
# 7   {'path': '/mnt/datasets/public/research/synbol...
# 12  {'path': '/mnt/datasets/public/research/synbol...
# 13  {'path': '/mnt/datasets/public/research/synbol...
# 18  {'path': '/mnt/datasets/public/research/synbol...
# 19  {'path': '/mnt/datasets/public/research/synbol...

# %%
# please define the path to the experiments
savedir_base = "/mnt/projects/bayesian-active-learning/synbols_ckpt"
from benchmarks.scripts.active_learning import EXP_GROUPS
exp_list = EXP_GROUPS['active_char_betabald']

# get specific experiments, for example, {'model':'resnet34'}
filterby_list = None
# group the experiments based on a hyperparameter, for example, ['dataset']
groupby_list = None
verbose = 0

# plot vars
y_metrics='test_loss'
x_metric='num_samples'
log_metric_list = ['train_loss']
map_exp_list = []
title_list=['query_size']
legend_list=['heuristic', 'iterations']
avg_across='seed'
legend_format = '{}, I={}'

# get experiments
rm = hr.ResultManager(exp_list=exp_list,
                      savedir_base=savedir_base,
                      filterby_list=filterby_list,
                      verbose=verbose
                     )
kwargs = {
    'y_metric': y_metrics,
    'x_metric': x_metric,
    'log_metric_list': log_metric_list,
    'map_exp_list': map_exp_list,
    'title_list':title_list,
    'legend_list': legend_list,
    'avg_across': avg_across,
    'figsize': (20, 15),
    'legend_format': legend_format,
    'groupby_list': ['query_size']
}


# launch dashboard
rm.get_plot(**kwargs)
# Out:
# [<Figure size 1440x1080 with 1 Axes>]

# %%
# please define the path to the experiments
savedir_base = "/mnt/projects/bayesian-active-learning/synbols_ckpt"
from benchmarks.scripts.active_learning import EXP_GROUPS
exp_list = EXP_GROUPS['active_char_mixup']

# get specific experiments, for example, {'model':'resnet34'}
filterby_list = None
# group the experiments based on a hyperparameter, for example, ['dataset']
groupby_list = None
verbose = 0

# plot vars
y_metrics='test_loss'
x_metric='num_samples'
log_metric_list = ['train_loss']
map_exp_list = []
title_list=['query_size']
legend_list=['heuristic', 'iterations', 'mixup_alpha']
avg_across='seed'
legend_format = '{}, I={}, Alpha={}'

# get experiments
rm = hr.ResultManager(exp_list=exp_list,
                      savedir_base=savedir_base,
                      filterby_list=filterby_list,
                      verbose=verbose
                     )
kwargs = {
    'y_metric': y_metrics,
    'x_metric': x_metric,
    'log_metric_list': log_metric_list,
    'map_exp_list': map_exp_list,
    'title_list':title_list,
    'legend_list': legend_list,
    'avg_across': avg_across,
    'figsize': (20, 15),
    'legend_format': legend_format,
    'groupby_list': ['query_size']
}


# launch dashboard
rm.get_plot(**kwargs)
# Out:
# [<Figure size 1440x1080 with 1 Axes>]

# %%
# Specify variables
from haven import haven_jupyter as hj
from haven import haven_results as hr
from haven import haven_utils as s
from haven import haven_utils as hu
import matplotlib as mpl
mpl.rc('image', cmap='tab20c')


# please define the path to the experiments
savedir_base = "/mnt/projects/bayesian-active-learning/synbols_ckpt"
from benchmarks.scripts.active_learning import EXP_GROUPS
exp_list = EXP_GROUPS['active_char_label_noise']

# get specific experiments, for example, {'model':'resnet34'}
filterby_list = None
# group the experiments based on a hyperparameter, for example, ['dataset']
groupby_list = None
verbose = 0

# plot vars
y_metrics='test_loss'
x_metric='num_samples'
log_metric_list = ['train_loss']
map_exp_list = []
title_list=['query_size']
legend_list=['heuristic', 'iterations']
avg_across='seed'
legend_format = '{}, I={}'

# get experiments
rm = hr.ResultManager(exp_list=exp_list,
                      savedir_base=savedir_base,
                      filterby_list=filterby_list,
                      verbose=verbose
                     )
kwargs = {
    'y_metric': y_metrics,
    'x_metric': x_metric,
    'log_metric_list': log_metric_list,
    'map_exp_list': map_exp_list,
    'title_list':title_list,
    'legend_list': legend_list,
    'avg_across': avg_across,
    'figsize': (20, 15),
    'legend_format': legend_format,
    'groupby_list': ['query_size']
}

df = rm.get_exp_list_df()

# launch dashboard
rm.get_plot(**kwargs)
# Out:
# [<Figure size 1440x1080 with 1 Axes>]

# %%
# Specify variables
from haven import haven_jupyter as hj
from haven import haven_results as hr
from haven import haven_utils as s
from haven import haven_utils as hu
import matplotlib as mpl
mpl.rc('image', cmap='tab20c')


# please define the path to the experiments
savedir_base = "/mnt/projects/bayesian-active-learning/synbols_ckpt"
from benchmarks.scripts.old_active_learning import EXP_GROUPS
exp_list = EXP_GROUPS['active_char_pixel_noise']

# get specific experiments, for example, {'model':'resnet34'}
filterby_list = None
# group the experiments based on a hyperparameter, for example, ['dataset']
groupby_list = None
verbose = 0

# plot vars
y_metrics='test_loss'
x_metric='num_samples'
log_metric_list = ['train_loss']
map_exp_list = []
title_list=['query_size']
legend_list=['heuristic', 'iterations']
avg_across='seed'
legend_format = '{}, I={}'

# get experiments
rm = hr.ResultManager(exp_list=exp_list,
                      savedir_base=savedir_base,
                      filterby_list=filterby_list,
                      verbose=verbose
                     )
kwargs = {
    'y_metric': y_metrics,
    'x_metric': x_metric,
    'log_metric_list': log_metric_list,
    'map_exp_list': map_exp_list,
    'title_list':title_list,
    'legend_list': legend_list,
    'avg_across': avg_across,
    'figsize': (10, 5),
    'legend_format': legend_format,
    'groupby_list': ['query_size']
}

df = rm.get_exp_list_df()

# launch dashboard
rm.get_plot(**kwargs)#%%
# Out:
# [<Figure size 720x360 with 1 Axes>]

# %%
# Specify variables
from haven import haven_jupyter as hj
from haven import haven_results as hr
from haven import haven_utils as s
from haven import haven_utils as hu
import matplotlib as mpl
mpl.rc('image', cmap='tab20c')


# please define the path to the experiments
savedir_base = "/mnt/projects/bayesian-active-learning/synbols_ckpt"
from benchmarks.scripts.old_active_learning import EXP_GROUPS
exp_list = EXP_GROUPS['active_char_label_noise']

# get specific experiments, for example, {'model':'resnet34'}
filterby_list = None
# group the experiments based on a hyperparameter, for example, ['dataset']
groupby_list = None
verbose = 0

# plot vars
y_metrics='test_loss'
x_metric='num_samples'
log_metric_list = ['train_loss']
map_exp_list = []
title_list=['query_size']
legend_list=['heuristic', 'iterations']
avg_across='seed'
legend_format = '{}, I={}'

# get experiments
rm = hr.ResultManager(exp_list=exp_list,
                      savedir_base=savedir_base,
                      filterby_list=filterby_list,
                      verbose=verbose
                     )
kwargs = {
    'y_metric': y_metrics,
    'x_metric': x_metric,
    'log_metric_list': log_metric_list,
    'map_exp_list': map_exp_list,
    'title_list':title_list,
    'legend_list': legend_list,
    'avg_across': avg_across,
    'figsize': (10, 5),
    'legend_format': legend_format,
    'groupby_list': ['query_size']
}

df = rm.get_exp_list_df()

# launch dashboard
rm.get_plot(**kwargs)
# Out:
# [<Figure size 720x360 with 1 Axes>]

# %%
# Specify variables
from haven import haven_jupyter as hj
from haven import haven_results as hr
from haven import haven_utils as s
from haven import haven_utils as hu
import matplotlib as mpl
mpl.rc('image', cmap='tab20c')


# please define the path to the experiments
savedir_base = "/mnt/projects/bayesian-active-learning/synbols_ckpt"
from benchmarks.scripts.old_active_learning import EXP_GROUPS
exp_list = EXP_GROUPS['active_char_calibrated']

# get specific experiments, for example, {'model':'resnet34'}
filterby_list = None
# group the experiments based on a hyperparameter, for example, ['dataset']
groupby_list = None
verbose = 0

# plot vars
y_metrics='test_loss'
x_metric='num_samples'
log_metric_list = ['train_loss']
map_exp_list = []
title_list=['query_size']
legend_list=['heuristic', 'iterations', 'calibrate']
avg_across='seed'
legend_format = '{}, I={}, Calibrate={}'

# get experiments
rm = hr.ResultManager(exp_list=exp_list,
                      savedir_base=savedir_base,
                      filterby_list=filterby_list,
                      verbose=verbose
                     )
kwargs = {
    'y_metric': y_metrics,
    'x_metric': x_metric,
    'log_metric_list': log_metric_list,
    'map_exp_list': map_exp_list,
    'title_list':title_list,
    'legend_list': legend_list,
    'avg_across': avg_across,
    'figsize': (20, 15),
    'legend_format': legend_format,
    'groupby_list': []
}

df = rm.get_exp_list_df()

# launch dashboard
rm.get_plot(**kwargs)
# Out:
# [<Figure size 1440x1080 with 1 Axes>]

# %%
print(df.columns)

df2 = df[df['heuristic'] == 'entropy']
df2 = df2[df2['query_size'] == 100]
df2 = df2[df2['calibrate'] == False]
print(df2['exp_id'])
# Out:
# Index(['exp_id', 'lr', 'batch_size', 'model', 'calibrate', 'seed', 'mu',
#        'reg_factor', 'backbone', 'num_classes', 'query_size', 'learning_epoch',
#        'heuristic', 'iterations', 'max_epoch', 'imagenet_pretraining',
#        'dataset'],
#       dtype='object')
# 2     d3e909536729c8fca4746de5f9040c27
# 5     7469bf54070bcb7d2d719bf3b0791269
# 8     7e37f0e96a15357a78052ccbca6ddd97
# 11    06ceef5d00931ed64efd02153f025d0e
# Name: exp_id, dtype: object

# %%
print(df.columns)

df2 = df[df['heuristic'] == 'entropy']
df2 = df2[df2['query_size'] == 100]
df2 = df2[df2['iterations'] == 20]
print(df2['exp_id'])
# Out:
# Index(['exp_id', 'lr', 'batch_size', 'model', 'seed', 'mu', 'reg_factor',
#        'backbone', 'num_classes', 'query_size', 'learning_epoch', 'heuristic',
#        'iterations', 'max_epoch', 'imagenet_pretraining', 'dataset'],
#       dtype='object')
# 57    1e098eed78c5044fe470769409260b3e
# 69    9b994f8dd1eecae17fc80bd8310b7638
# 81    74d2a210dd3c5deed7f8ac792e86c374
# 93    8d830d94697b22bfcad42cb9d0012d23
# Name: exp_id, dtype: object
